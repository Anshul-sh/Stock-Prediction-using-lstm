# %%
import yfinance as yf
import datetime as dt
import os
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import CSVLogger


def Percentage_Accuracy(y_true, y_pred):
    diff = keras.backend.abs(y_true-y_pred)
    correct = keras.backend.less(diff,0.06) 
    return keras.backend.mean(correct)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = yf.download("AAPL", start="2010-01-01", end="2020-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04   7.622500   7.660714   7.585000   7.643214   6.593426  493729600
# 2010-01-05   7.664286   7.699643   7.616071   7.656428   6.604825  601904800
# 2010-01-06   7.656428   7.686786   7.526786   7.534643   6.499768  552160000
# 2010-01-07   7.562500   7.571429   7.466072   7.520714   6.487752  477131200
# 2010-01-08   7.510714   7.571429   7.466429   7.570714   6.530883  447610800
# ...               ...        ...        ...        ...        ...        ...
# 2020-04-23  68.967499  70.437500  68.717499  68.757500  68.330582  124814400
# 2020-04-24  69.300003  70.752502  69.250000  70.742500  70.303253  126508800
# 2020-04-27  70.449997  71.135002  69.987503  70.792503  70.352943  117087600
# 2020-04-28  71.269997  71.457497  69.550003  69.644997  69.212555  112004800
# 2020-04-29  71.182503  72.417503  70.972504  71.932503  71.485863  137280800
#
# [2598 rows x 6 columns]

# %%
plt.figure(figsize=(14,14))
plt.plot(data['Open'], label='Open Price')
plt.plot(data['Close'], label='Close Price')
plt.title('Historical Stock Value')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
data['Date'] = data.index
filter_data = pd.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close'])
filter_data['Date'] = data['Date']
filter_data['Open'] = data['Open']
filter_data['High'] = data['High']
filter_data['Low'] = data['Low']
filter_data['Close'] = data['Close']

# %%
filter_data
# Out:
#                  Date       Open       High        Low      Close
# Date
# 2010-01-04 2010-01-04   7.622500   7.660714   7.585000   7.643214
# 2010-01-05 2010-01-05   7.664286   7.699643   7.616071   7.656428
# 2010-01-06 2010-01-06   7.656428   7.686786   7.526786   7.534643
# 2010-01-07 2010-01-07   7.562500   7.571429   7.466072   7.520714
# 2010-01-08 2010-01-08   7.510714   7.571429   7.466429   7.570714
# ...               ...        ...        ...        ...        ...
# 2020-04-23 2020-04-23  68.967499  70.437500  68.717499  68.757500
# 2020-04-24 2020-04-24  69.300003  70.752502  69.250000  70.742500
# 2020-04-27 2020-04-27  70.449997  71.135002  69.987503  70.792503
# 2020-04-28 2020-04-28  71.269997  71.457497  69.550003  69.644997
# 2020-04-29 2020-04-29  71.182503  72.417503  70.972504  71.932503
#
# [2598 rows x 5 columns]

# %%
training_set = filter_data.iloc[:1700, 2:3].values
test_set = filter_data.iloc[1700:, 2:3].values
sc = MinMaxScaler(feature_range = (-1, 1))

# %%
#Training Data
training_set_scaled = sc.fit_transform(training_set)
X_train = []
y_train = []
for i in range(30, len(training_set)):
    X_train.append(training_set_scaled[i-30:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
#Test Data
total_data =filter_data.iloc[:, 2:3]
inputs = total_data[len(total_data) - len(test_set) - 30:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
y_test = []
for i in range(30, len(inputs)):
    X_test.append(inputs[i-30:i, 0])
    y_test.append(training_set_scaled[i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
#Defining the LSTM Recurrent Model
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
#Compiling and fitting the model
csv_logger = CSVLogger("model_history_log.csv")
opt = keras.optimizers.Adamax()
lossfunction = keras.losses.mse
regressor.compile(optimizer = opt, loss = lossfunction, metrics=[Percentage_Accuracy])
regressor.fit(X_train, y_train, epochs = 50, batch_size =16 ,callbacks=[csv_logger], validation_split=0.2)
# Out:
# Epoch 1/50
# 84/84 [==============================] - 7s 25ms/step - loss: 0.0646 - Percentage_Accuracy: 0.2743 - val_loss: 0.0169 - val_Percentage_Accuracy: 0.3975
# Epoch 2/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0094 - Percentage_Accuracy: 0.4765 - val_loss: 0.0133 - val_Percentage_Accuracy: 0.4226
# Epoch 3/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0084 - Percentage_Accuracy: 0.4830 - val_loss: 0.0119 - val_Percentage_Accuracy: 0.4307
# Epoch 4/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0085 - Percentage_Accuracy: 0.5093 - val_loss: 0.0136 - val_Percentage_Accuracy: 0.3754
# Epoch 5/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0077 - Percentage_Accuracy: 0.5409 - val_loss: 0.0091 - val_Percentage_Accuracy: 0.4617
# Epoch 6/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0078 - Percentage_Accuracy: 0.5161 - val_loss: 0.0091 - val_Percentage_Accuracy: 0.4630
# Epoch 7/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0068 - Percentage_Accuracy: 0.5375 - val_loss: 0.0088 - val_Percentage_Accuracy: 0.4571
# Epoch 8/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0065 - Percentage_Accuracy: 0.5549 - val_loss: 0.0145 - val_Percentage_Accuracy: 0.3380
# Epoch 9/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0067 - Percentage_Accuracy: 0.5639 - val_loss: 0.0085 - val_Percentage_Accuracy: 0.4630
# Epoch 10/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0061 - Percentage_Accuracy: 0.5887 - val_loss: 0.0076 - val_Percentage_Accuracy: 0.4966
# Epoch 11/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0057 - Percentage_Accuracy: 0.5911 - val_loss: 0.0073 - val_Percentage_Accuracy: 0.5055
# Epoch 12/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0060 - Percentage_Accuracy: 0.5794 - val_loss: 0.0075 - val_Percentage_Accuracy: 0.4877
# Epoch 13/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0061 - Percentage_Accuracy: 0.5347 - val_loss: 0.0096 - val_Percentage_Accuracy: 0.4405
# Epoch 14/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0056 - Percentage_Accuracy: 0.5992 - val_loss: 0.0065 - val_Percentage_Accuracy: 0.5493
# Epoch 15/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0057 - Percentage_Accuracy: 0.5991 - val_loss: 0.0062 - val_Percentage_Accuracy: 0.5621
# Epoch 16/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0064 - Percentage_Accuracy: 0.5765 - val_loss: 0.0064 - val_Percentage_Accuracy: 0.5204
# Epoch 17/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0051 - Percentage_Accuracy: 0.6178 - val_loss: 0.0060 - val_Percentage_Accuracy: 0.5472
# Epoch 18/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0053 - Percentage_Accuracy: 0.6249 - val_loss: 0.0070 - val_Percentage_Accuracy: 0.5387
# Epoch 19/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0050 - Percentage_Accuracy: 0.5913 - val_loss: 0.0056 - val_Percentage_Accuracy: 0.5918
# Epoch 20/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0052 - Percentage_Accuracy: 0.6028 - val_loss: 0.0132 - val_Percentage_Accuracy: 0.3810
# Epoch 21/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0057 - Percentage_Accuracy: 0.5827 - val_loss: 0.0054 - val_Percentage_Accuracy: 0.6037
# Epoch 22/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0053 - Percentage_Accuracy: 0.5973 - val_loss: 0.0056 - val_Percentage_Accuracy: 0.5923
# Epoch 23/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0052 - Percentage_Accuracy: 0.6232 - val_loss: 0.0068 - val_Percentage_Accuracy: 0.5446
# Epoch 24/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0057 - Percentage_Accuracy: 0.5816 - val_loss: 0.0057 - val_Percentage_Accuracy: 0.5591
# Epoch 25/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0056 - Percentage_Accuracy: 0.6301 - val_loss: 0.0074 - val_Percentage_Accuracy: 0.5085
# Epoch 26/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0048 - Percentage_Accuracy: 0.6441 - val_loss: 0.0058 - val_Percentage_Accuracy: 0.5893
# Epoch 27/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0049 - Percentage_Accuracy: 0.6405 - val_loss: 0.0043 - val_Percentage_Accuracy: 0.6633
# Epoch 28/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0048 - Percentage_Accuracy: 0.6106 - val_loss: 0.0045 - val_Percentage_Accuracy: 0.6276
# Epoch 29/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0044 - Percentage_Accuracy: 0.6462 - val_loss: 0.0044 - val_Percentage_Accuracy: 0.6671
# Epoch 30/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0048 - Percentage_Accuracy: 0.6436 - val_loss: 0.0063 - val_Percentage_Accuracy: 0.5706
# Epoch 31/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0050 - Percentage_Accuracy: 0.6418 - val_loss: 0.0042 - val_Percentage_Accuracy: 0.6429
# Epoch 32/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0040 - Percentage_Accuracy: 0.6907 - val_loss: 0.0059 - val_Percentage_Accuracy: 0.5859
# Epoch 33/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0050 - Percentage_Accuracy: 0.6473 - val_loss: 0.0051 - val_Percentage_Accuracy: 0.6156
# Epoch 34/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0046 - Percentage_Accuracy: 0.6364 - val_loss: 0.0061 - val_Percentage_Accuracy: 0.5553
# Epoch 35/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0048 - Percentage_Accuracy: 0.6358 - val_loss: 0.0041 - val_Percentage_Accuracy: 0.7032
# Epoch 36/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0045 - Percentage_Accuracy: 0.6591 - val_loss: 0.0047 - val_Percentage_Accuracy: 0.6637
# Epoch 37/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0045 - Percentage_Accuracy: 0.6691 - val_loss: 0.0037 - val_Percentage_Accuracy: 0.7181
# Epoch 38/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0046 - Percentage_Accuracy: 0.6426 - val_loss: 0.0081 - val_Percentage_Accuracy: 0.4902
# Epoch 39/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0049 - Percentage_Accuracy: 0.6474 - val_loss: 0.0036 - val_Percentage_Accuracy: 0.7062
# Epoch 40/50
# 84/84 [==============================] - 1s 12ms/step - loss: 0.0047 - Percentage_Accuracy: 0.6313 - val_loss: 0.0035 - val_Percentage_Accuracy: 0.7181
# Epoch 41/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0042 - Percentage_Accuracy: 0.6635 - val_loss: 0.0038 - val_Percentage_Accuracy: 0.6905
# Epoch 42/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0046 - Percentage_Accuracy: 0.6613 - val_loss: 0.0038 - val_Percentage_Accuracy: 0.7334
# Epoch 43/50
# 84/84 [==============================] - 1s 11ms/step - loss: 0.0039 - Percentage_Accuracy: 0.6845 - val_loss: 0.0034 - val_Percentage_Accuracy: 0.7270
# Epoch 44/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0038 - Percentage_Accuracy: 0.7014 - val_loss: 0.0064 - val_Percentage_Accuracy: 0.5319
# Epoch 45/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0039 - Percentage_Accuracy: 0.6824 - val_loss: 0.0031 - val_Percentage_Accuracy: 0.7270
# Epoch 46/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0040 - Percentage_Accuracy: 0.6690 - val_loss: 0.0030 - val_Percentage_Accuracy: 0.7330
# Epoch 47/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0040 - Percentage_Accuracy: 0.6722 - val_loss: 0.0031 - val_Percentage_Accuracy: 0.7419
# Epoch 48/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0040 - Percentage_Accuracy: 0.6942 - val_loss: 0.0030 - val_Percentage_Accuracy: 0.7513
# Epoch 49/50
# 84/84 [==============================] - 1s 14ms/step - loss: 0.0036 - Percentage_Accuracy: 0.6975 - val_loss: 0.0048 - val_Percentage_Accuracy: 0.6373
# Epoch 50/50
# 84/84 [==============================] - 1s 13ms/step - loss: 0.0033 - Percentage_Accuracy: 0.7203 - val_loss: 0.0028 - val_Percentage_Accuracy: 0.7662

# %%
model_log_data = pd.read_csv("model_history_log.csv")
plt.plot(model_log_data["epoch"].values, model_log_data["loss"].values, label = "Loss")
plt.plot(model_log_data["epoch"].values, model_log_data["val_loss"].values, label = "Validation Loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Variation and loss function with epoch on Closing Price')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()
plt.plot(model_log_data["epoch"].values, model_log_data["Percentage_Accuracy"].values, label = "Percentage Accuracy")
plt.plot(model_log_data["epoch"].values, model_log_data["val_Percentage_Accuracy"].values, label = "Validation Percentage Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Variation accuracy and loss accuracy with epoch on Closing Price')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
predicted_value = regressor.predict(X_test)
predicted_value = sc.inverse_transform(predicted_value)

# %%
plt.figure(figsize=(20,10))
plt.plot(test_set, color = 'green', label = 'Actual Price')
plt.plot(predicted_value, color = 'red', label = 'Predicted Price')
plt.title('Stock Prediction on Closing Price')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()
plt.show()
